# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('Customers.csv')

# %%
df.head(15)
# Out:
#     CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0            1    Male   19              15000                      39
# 1            2    Male   21              35000                      81
# 2            3  Female   20              86000                       6
# 3            4  Female   23              59000                      77
# 4            5  Female   31              38000                      40
# 5            6  Female   22              58000                      76
# 6            7  Female   35              31000                       6
# 7            8  Female   23              84000                      94
# 8            9    Male   64              97000                       3
# 9           10  Female   30              98000                      72
# 10          11    Male   67               7000                      14
# 11          12  Female   35              93000                      99
# 12          13  Female   58              80000                      15
# 13          14  Female   24              91000                      77
# 14          15    Male   37              19000                      13
#
#        Profession  Work Experience  Family Size
# 0      Healthcare                1            4
# 1        Engineer                3            3
# 2        Engineer                1            1
# 3          Lawyer                0            2
# 4   Entertainment                2            6
# 5          Artist                0            2
# 6      Healthcare                1            3
# 7      Healthcare                1            3
# 8        Engineer                0            3
# 9          Artist                1            4
# 10       Engineer                1            3
# 11     Healthcare                4            4
# 12      Executive                0            5
# 13         Lawyer                1            1
# 14         Doctor                0            1

# %%
df.shape
# Out:
# (2000, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]>

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       CustomerID  Gender    Age  Annual Income ($)  Spending Score (1-100)  \
# 0          False   False  False              False                   False
# 1          False   False  False              False                   False
# 2          False   False  False              False                   False
# 3          False   False  False              False                   False
# 4          False   False  False              False                   False
# ...          ...     ...    ...                ...                     ...
# 1995       False   False  False              False                   False
# 1996       False   False  False              False                   False
# 1997       False   False  False              False                   False
# 1998       False   False  False              False                   False
# 1999       False   False  False              False                   False
#
#       Profession  Work Experience  Family Size
# 0          False            False        False
# 1          False            False        False
# 2          False            False        False
# 3          False            False        False
# 4          False            False        False
# ...          ...              ...          ...
# 1995       False            False        False
# 1996       False            False        False
# 1997       False            False        False
# 1998       False            False        False
# 1999       False            False        False
#
# [2000 rows x 8 columns]>

# %%
X= df.iloc[:,[3,4]].values

# %%
print(X)
# Out:
# [[ 15000     39]
#  [ 35000     81]
#  [ 86000      6]
#  ...
#  [ 90961     14]
#  [182109      4]
#  [110610     52]]

# %%
from sklearn.cluster import KMeans
wcss =[]

# %%
for i in range(1, 11):
  kmeans = skc.KMeans(n_clusters=i, init='k-means++', random_state=0)
  kmeans.fit(X)
  wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Sridip\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=8.
#   warnings.warn(

# %%
plt.plot(range(1,11), wcss)
plt.title('The elbow method')
plt.xlabel('No. of cluster')
plt.ylabel('WCSS values')
plt.show()

# %%
kmeansmodel = KMeans(n_clusters=5, init='k-means++', random_state=0)

# %%
y_kmeans = kmeansmodel.fit_predict(X)

# %%
plt.scatter(X[y_kmeans ==0,0], X[y_kmeans ==0,1], s=80, c="red", label='Customer 1')
plt.scatter(X[y_kmeans ==1,0], X[y_kmeans ==1,1], s=80, c="blue", label='Customer 2')
plt.scatter(X[y_kmeans ==2,0], X[y_kmeans ==2,1], s=80, c="yellow", label='Customer 3')
plt.scatter(X[y_kmeans ==3,0], X[y_kmeans ==3,1], s=80, c="cyan", label='Customer 4')
plt.scatter(X[y_kmeans ==4,0], X[y_kmeans ==4,1], s=80, c="green", label='Customer 5')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], s=100, c='magenta' , label='Centroids')
plt.title('Cluster of customer')
plt.xlabel('Annual Income($)')
plt.ylabel('Spending Score(1-100)')
plt.legend()
plt.show()

# %%
# Out:
# Requirement already satisfied: notebook-as-pdf in c:\users\sridip\anaconda3\lib\site-packages (0.5.0)
# Requirement already satisfied: nbconvert in c:\users\sridip\anaconda3\lib\site-packages (from notebook-as-pdf) (6.4.4)
# Requirement already satisfied: pyppeteer in c:\users\sridip\anaconda3\lib\site-packages (from notebook-as-pdf) (2.0.0)
# Requirement already satisfied: PyPDF2 in c:\users\sridip\anaconda3\lib\site-packages (from notebook-as-pdf) (3.0.1)
# Requirement already satisfied: defusedxml in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.7.1)
# Requirement already satisfied: nbformat>=4.4 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (5.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (4.11.1)
# Requirement already satisfied: testpath in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (4.11.1)
# Requirement already satisfied: jinja2>=2.4 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (3.1.3)
# Requirement already satisfied: bleach in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (4.1.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (2.11.2)
# Requirement already satisfied: traitlets>=5.0 in c:\users\sridip\anaconda3\lib\site-packages (from nbconvert->notebook-as-pdf) (5.1.1)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\sridip\anaconda3\lib\site-packages (from PyPDF2->notebook-as-pdf) (4.3.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (4.11.3)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (11.1.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (1.26.11)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (1.4.4)
# Requirement already satisfied: certifi>=2023 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (2024.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (4.64.1)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\sridip\anaconda3\lib\site-packages (from pyppeteer->notebook-as-pdf) (10.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\sridip\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer->notebook-as-pdf) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sridip\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert->notebook-as-pdf) (2.0.1)
# Requirement already satisfied: nest-asyncio in c:\users\sridip\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook-as-pdf) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\sridip\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook-as-pdf) (7.3.4)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\sridip\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert->notebook-as-pdf) (4.16.0)
# Requirement already satisfied: fastjsonschema in c:\users\sridip\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert->notebook-as-pdf) (2.16.2)
# Requirement already satisfied: colorama in c:\users\sridip\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer->notebook-as-pdf) (0.4.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sridip\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook-as-pdf) (2.3.1)
# Requirement already satisfied: packaging in c:\users\sridip\anaconda3\lib\site-packages (from bleach->nbconvert->notebook-as-pdf) (21.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\sridip\anaconda3\lib\site-packages (from bleach->nbconvert->notebook-as-pdf) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\sridip\anaconda3\lib\site-packages (from bleach->nbconvert->notebook-as-pdf) (0.5.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sridip\anaconda3\lib\site-packages (from jupyter-core->nbconvert->notebook-as-pdf) (302)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\sridip\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->notebook-as-pdf) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\sridip\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert->notebook-as-pdf) (21.4.0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\sridip\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert->notebook-as-pdf) (23.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sridip\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert->notebook-as-pdf) (2.8.2)
# Requirement already satisfied: tornado>=6.0 in c:\users\sridip\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert->notebook-as-pdf) (6.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\sridip\anaconda3\lib\site-packages (from packaging->bleach->nbconvert->notebook-as-pdf) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
